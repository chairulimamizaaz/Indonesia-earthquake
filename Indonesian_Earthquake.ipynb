# %% [markdown]
# <a href="https://colab.research.google.com/github/chairulimamizaaz/Indonesia-earthquake/blob/main/Indonesian_Earthquake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Earthquakes are natural phenomena that have significant impacts on human societies and the environment. Understanding the patterns and characteristics of earthquake occurrences is crucial for disaster preparedness, risk mitigation, and the development of resilient communities. In this project, we explore earthquake data sourced from the Earthquake Repository managed by BMKG (Indonesian Meteorology, Climatology, and Geophysical Agency), an authoritative organization responsible for monitoring seismic activities in Indonesia.
#
# This dataset originates from the Earthquake Repository managed by BMKG, an Indonesian non-departmental government agency. BMKG underwent a redesign of their website in early 2023, resulting in two distinct datasets. The new dataset is sourced from the Preliminary Earthquake Catalog, which incorporates focal mechanism data. It encompasses earthquake event records from November 1, 2008, to December 15, 2023, although the accuracy of some of the latest recorded earthquake events may vary.
#
# In this project, our objective is to analyze and explore the earthquake data to uncover insights into earthquake patterns, characteristics, and their relationships with geographical locations. Specifically, we aim to address several key questions, including:
#
# 1. How do earthquake occurrences vary over time based on date, month, and year?
# 2. Is there a correlation between the depth of earthquakes and the magnitude of earthquakes?
# 3. What influence do geographical locations have on the depth and magnitude of earthquakes?
# 4. Are there any seasonal patterns or trends in earthquake magnitudes over time?
#
# By addressing these questions, we aim to contribute to the understanding of seismic activities, enhance disaster preparedness efforts, and support decision-making processes for mitigating earthquake risks in Indonesia and beyond.
#
# # Objective
#
# 1. Analyze the temporal variation of earthquake occurrences based on date, month, and year to identify trends and patterns in seismic activity over time.
# 2. Investigate the correlation between the depth of earthquakes and the magnitude of earthquakes to determine if there is a relationship between these two factors.
# 3. Assess the influence of geographical locations on the depth and magnitude of earthquakes to understand how different regions are affected by seismic events.
# 4. Identify seasonal patterns or trends in earthquake magnitudes over time to determine if there are recurring patterns in seismic activity related to specific seasons or periods.
#
# # DATA
#
# This dataset is obtained from the Earthquake Repository managed by BMKG (the Indonesian Meteorology, Climatology, and Geophysical Agency), a non-departmental government agency. BMKG underwent a redesign of their website in early 2023, resulting in the creation of two distinct datasets.
#
# The variables included in this dataset are as follows:
#
# * tgl: Date of the event
# * ot: Timestamp of the event
# * lat: Latitude of the event epicenter, measured in degrees,ranging from 6N to 11S
# * lon: Longitude of the event epicenter, measured in degrees, ranging from 142E to 94E
# * depth: Depth of the event, measured in kilometers
# * mag: Magnitude of the event, ranging from 1 to 9.5
# * remark: Flinn-Engdahl regions of the event
#
# there is additional data such as magnitude level, and dates will be broken down into day, date, month, year and hour. These are the variables available in this earthquake dataset.

# %%
import pandas as pd
data_gempa = '/content/drive/MyDrive/dataset/katalog_gempa.csv'
df = pd.read_csv(data_gempa)

# %%
display(df)
# Out:
#               tgl            ot   lat     lon  depth  mag  \
# 0      2008/11/01  21:02:43.058 -9.18  119.06     10  4.9
# 1      2008/11/01  20:58:50.248 -6.55  129.64     10  4.6
# 2      2008/11/01  17:43:12.941 -7.01  106.63    121  3.7
# 3      2008/11/01  16:24:14.755 -3.30  127.85     10  3.2
# 4      2008/11/01  16:20:37.327 -6.41  129.54     70  4.3
# ...           ...           ...   ...     ...    ...  ...
# 92882  2023/01/26  02:25:09.288  3.24  127.18     10  4.0
# 92883  2023/01/26  02:15:03.893  2.70  127.10     10  3.9
# 92884  2023/01/26  01:57:08.885 -7.83  121.07     10  3.8
# 92885  2023/01/26  01:46:21.009  3.00  127.16     10  4.1
# 92886  2023/01/26  00:00:35.181 -8.87  118.95     10  2.4
#
#                            remark  strike1  dip1  rake1  strike2  dip2  rake2
# 0        Sumba Region - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 1                       Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 2                Java - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 3               Seram - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 4                       Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN
# ...                           ...      ...   ...    ...      ...   ...    ...
# 92882  Talaud Islands - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 92883        Northern Molucca Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 92884                  Flores Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 92885        Northern Molucca Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 92886  Sumbawa Region - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
#
# [92887 rows x 13 columns]

# %%
df.sample(10)
# Out:
#               tgl            ot   lat     lon  depth  mag  \
# 47480  2018/11/11  00:21:40.073 -0.02  124.24     61  3.2
# 73316  2021/05/03  15:22:35.005 -3.18  140.21     10  2.5
# 18096  2014/07/23  02:17:48.693 -8.47  108.47     13  3.9
# 66245  2020/07/21  21:33:10.233  2.71  125.46    141  4.2
# 41070  2018/06/23  07:38:28.670 -3.08  130.91     10  3.1
# 55988  2019/07/13  08:37:14.039 -6.08  130.71    141  4.8
# 86252  2022/07/04  02:57:52.663 -9.60  118.92     23  4.0
# 66834  2020/08/15  15:26:26.326 -9.35  113.91     25  2.9
# 11721  2012/04/24  04:27:39.755 -9.11  115.18     76  2.4
# 79653  2021/12/07  22:18:33.565 -6.72  107.34     10  3.4
#
#                            remark  strike1  dip1  rake1  strike2  dip2  rake2
# 47480        Southern Molucca Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 73316      Irian Jaya - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 18096            Java - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 66245  Talaud Islands - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 41070           Seram - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 55988                   Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 86252  Sumbawa Region - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 66834   South of Java - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 11721   South of Bali - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 79653            Java - Indonesia    166.9  42.3  175.8   259.98  87.2   47.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92887 entries, 0 to 92886
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tgl      92887 non-null  object
#  1   ot       92887 non-null  object
#  2   lat      92887 non-null  float64
#  3   lon      92887 non-null  float64
#  4   depth    92887 non-null  int64
#  5   mag      92887 non-null  float64
#  6   remark   92887 non-null  object
#  7   strike1  2735 non-null   float64
#  8   dip1     2735 non-null   float64
#  9   rake1    2735 non-null   float64
#  10  strike2  2735 non-null   float64
#  11  dip2     2735 non-null   float64
#  12  rake2    2735 non-null   float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 9.2+ MB

# %% [markdown]
# # Data Prepare

# %%
df['tgl'] = pd.to_datetime(df['tgl'])
df['ot'] = pd.to_datetime(df['ot'])
# Out:
# <ipython-input-5-e5f788a56543>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['ot'] = pd.to_datetime(df['ot'])

# %%
df['year'] = df['tgl'].dt.year
df['moon'] = df['tgl'].dt.month_name()
df['day'] = df['tgl'].dt.day_name()
df['time'] = df['ot'].dt.strftime('%H:%M:%S')

# %%
data_cleaned = ['strike1', 'dip1', 'rake1', 'strike2', 'dip2', 'rake2']
df = df.drop(columns=data_cleaned)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92887 entries, 0 to 92886
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tgl     92887 non-null  datetime64[ns]
#  1   ot      92887 non-null  datetime64[ns]
#  2   lat     92887 non-null  float64
#  3   lon     92887 non-null  float64
#  4   depth   92887 non-null  int64
#  5   mag     92887 non-null  float64
#  6   remark  92887 non-null  object
#  7   year    92887 non-null  int32
#  8   moon    92887 non-null  object
#  9   day     92887 non-null  object
#  10  time    92887 non-null  object
# dtypes: datetime64[ns](2), float64(3), int32(1), int64(1), object(4)
# memory usage: 7.4+ MB

# %%
df = df[['tgl', 'time', 'day', 'moon', 'year', 'depth', 'mag', 'remark', 'lat', 'lon']]
display(df)
# Out:
#              tgl      time       day      moon  year  depth  mag  \
# 0     2008-11-01  21:02:43  Saturday  November  2008     10  4.9
# 1     2008-11-01  20:58:50  Saturday  November  2008     10  4.6
# 2     2008-11-01  17:43:12  Saturday  November  2008    121  3.7
# 3     2008-11-01  16:24:14  Saturday  November  2008     10  3.2
# 4     2008-11-01  16:20:37  Saturday  November  2008     70  4.3
# ...          ...       ...       ...       ...   ...    ...  ...
# 92882 2023-01-26  02:25:09  Thursday   January  2023     10  4.0
# 92883 2023-01-26  02:15:03  Thursday   January  2023     10  3.9
# 92884 2023-01-26  01:57:08  Thursday   January  2023     10  3.8
# 92885 2023-01-26  01:46:21  Thursday   January  2023     10  4.1
# 92886 2023-01-26  00:00:35  Thursday   January  2023     10  2.4
#
#                            remark   lat     lon
# 0        Sumba Region - Indonesia -9.18  119.06
# 1                       Banda Sea -6.55  129.64
# 2                Java - Indonesia -7.01  106.63
# 3               Seram - Indonesia -3.30  127.85
# 4                       Banda Sea -6.41  129.54
# ...                           ...   ...     ...
# 92882  Talaud Islands - Indonesia  3.24  127.18
# 92883        Northern Molucca Sea  2.70  127.10
# 92884                  Flores Sea -7.83  121.07
# 92885        Northern Molucca Sea  3.00  127.16
# 92886  Sumbawa Region - Indonesia -8.87  118.95
#
# [92887 rows x 10 columns]

# %%
print("Nilai Null dalam DataFrame:")
print(df.isnull().sum())
print("\nJumlah Baris Duplikat dalam DataFrame:", df.duplicated().sum())
# Out:
# Nilai Null dalam DataFrame:
# tgl       0
# time      0
# day       0
# moon      0
# year      0
# depth     0
# mag       0
# remark    0
# lat       0
# lon       0
# dtype: int64
#
# Jumlah Baris Duplikat dalam DataFrame: 2735

# %%
df[df.duplicated()]
# Out:
#              tgl      time        day     moon  year  depth  mag  \
# 8740  2011-06-27  16:47:15     Monday     June  2011    139  5.7
# 8802  2011-07-04  05:17:37     Monday     July  2011     10  3.4
# 8805  2011-07-05  19:09:11    Tuesday     July  2011     13  4.8
# 8911  2011-07-19  03:18:38    Tuesday     July  2011     10  5.1
# 9027  2011-08-06  14:43:30   Saturday   August  2011     10  4.8
# ...          ...       ...        ...      ...   ...    ...  ...
# 92800 2023-01-24  02:13:19    Tuesday  January  2023     52  5.9
# 92802 2023-01-24  01:10:25    Tuesday  January  2023     10  5.0
# 92806 2023-01-25  19:10:59  Wednesday  January  2023     23  4.6
# 92865 2023-01-26  06:33:44   Thursday  January  2023     10  4.8
# 92873 2023-01-26  04:23:50   Thursday  January  2023     10  5.7
#
#                                    remark    lat     lon
# 8740                             Savu Sea  -9.28  122.46
# 8802         Northern Sumatra - Indonesia   4.37   97.52
# 8805   Off West Coast of Northern Sumatra   1.45   96.95
# 8911       Near North Coast of Irian Jaya  -1.27  137.83
# 9027                    Seram - Indonesia  -3.11  130.92
# ...                                   ...    ...     ...
# 92800                Northern Molucca Sea   2.84  127.04
# 92802                Northern Molucca Sea   2.81  127.03
# 92806           South of Java - Indonesia -10.76  111.74
# 92865                Northern Molucca Sea   2.93  127.03
# 92873          Talaud Islands - Indonesia   3.09  127.08
#
# [2735 rows x 10 columns]

# %%
df[df.duplicated(keep=False)]
# Out:
#              tgl      time        day     moon  year  depth  mag  \
# 8739  2011-06-27  16:47:15     Monday     June  2011    139  5.7
# 8740  2011-06-27  16:47:15     Monday     June  2011    139  5.7
# 8801  2011-07-04  05:17:37     Monday     July  2011     10  3.4
# 8802  2011-07-04  05:17:37     Monday     July  2011     10  3.4
# 8804  2011-07-05  19:09:11    Tuesday     July  2011     13  4.8
# ...          ...       ...        ...      ...   ...    ...  ...
# 92806 2023-01-25  19:10:59  Wednesday  January  2023     23  4.6
# 92864 2023-01-26  06:33:44   Thursday  January  2023     10  4.8
# 92865 2023-01-26  06:33:44   Thursday  January  2023     10  4.8
# 92872 2023-01-26  04:23:50   Thursday  January  2023     10  5.7
# 92873 2023-01-26  04:23:50   Thursday  January  2023     10  5.7
#
#                                    remark    lat     lon
# 8739                             Savu Sea  -9.28  122.46
# 8740                             Savu Sea  -9.28  122.46
# 8801         Northern Sumatra - Indonesia   4.37   97.52
# 8802         Northern Sumatra - Indonesia   4.37   97.52
# 8804   Off West Coast of Northern Sumatra   1.45   96.95
# ...                                   ...    ...     ...
# 92806           South of Java - Indonesia -10.76  111.74
# 92864                Northern Molucca Sea   2.93  127.03
# 92865                Northern Molucca Sea   2.93  127.03
# 92872          Talaud Islands - Indonesia   3.09  127.08
# 92873          Talaud Islands - Indonesia   3.09  127.08
#
# [5470 rows x 10 columns]

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tgl, time, day, moon, year, depth, mag, remark, lat, lon]
# Index: []

# %%
df.rename(columns = {'remark': 'Location', 'mag': 'Magnitude', 'depth': 'Depth (km)', 'tgl': 'Date', 'lat': 'Latitude', 'lon': 'Longitude'}, inplace = True)
df
# Out:
# <ipython-input-15-508cfd0f6457>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'remark': 'Location', 'mag': 'Magnitude', 'depth': 'Depth (km)', 'tgl': 'Date', 'lat': 'Latitude', 'lon': 'Longitude'}, inplace = True)
#             Date      time       day      moon  year  Depth (km)  Magnitude  \
# 0     2008-11-01  21:02:43  Saturday  November  2008          10        4.9
# 1     2008-11-01  20:58:50  Saturday  November  2008          10        4.6
# 2     2008-11-01  17:43:12  Saturday  November  2008         121        3.7
# 3     2008-11-01  16:24:14  Saturday  November  2008          10        3.2
# 4     2008-11-01  16:20:37  Saturday  November  2008          70        4.3
# ...          ...       ...       ...       ...   ...         ...        ...
# 92882 2023-01-26  02:25:09  Thursday   January  2023          10        4.0
# 92883 2023-01-26  02:15:03  Thursday   January  2023          10        3.9
# 92884 2023-01-26  01:57:08  Thursday   January  2023          10        3.8
# 92885 2023-01-26  01:46:21  Thursday   January  2023          10        4.1
# 92886 2023-01-26  00:00:35  Thursday   January  2023          10        2.4
#
#                          Location  Latitude  Longitude
# 0        Sumba Region - Indonesia     -9.18     119.06
# 1                       Banda Sea     -6.55     129.64
# 2                Java - Indonesia     -7.01     106.63
# 3               Seram - Indonesia     -3.30     127.85
# 4                       Banda Sea     -6.41     129.54
# ...                           ...       ...        ...
# 92882  Talaud Islands - Indonesia      3.24     127.18
# 92883        Northern Molucca Sea      2.70     127.10
# 92884                  Flores Sea     -7.83     121.07
# 92885        Northern Molucca Sea      3.00     127.16
# 92886  Sumbawa Region - Indonesia     -8.87     118.95
#
# [90152 rows x 10 columns]

# %%
def get_level(magnitude):
    if magnitude < 2.5:
        return 1
    elif magnitude < 5.4:
        return 2
    elif magnitude < 6.0:
        return 3
    elif magnitude < 6.9:
        return 4
    elif magnitude < 7.9:
        return 5
    else:
        return 6

df['Level'] = df['Magnitude'].apply(get_level)
df
# Out:
#             Date      time       day      moon  year  Depth (km)  Magnitude  \
# 0     2008-11-01  21:02:43  Saturday  November  2008          10        4.9
# 1     2008-11-01  20:58:50  Saturday  November  2008          10        4.6
# 2     2008-11-01  17:43:12  Saturday  November  2008         121        3.7
# 3     2008-11-01  16:24:14  Saturday  November  2008          10        3.2
# 4     2008-11-01  16:20:37  Saturday  November  2008          70        4.3
# ...          ...       ...       ...       ...   ...         ...        ...
# 92882 2023-01-26  02:25:09  Thursday   January  2023          10        4.0
# 92883 2023-01-26  02:15:03  Thursday   January  2023          10        3.9
# 92884 2023-01-26  01:57:08  Thursday   January  2023          10        3.8
# 92885 2023-01-26  01:46:21  Thursday   January  2023          10        4.1
# 92886 2023-01-26  00:00:35  Thursday   January  2023          10        2.4
#
#                          Location  Latitude  Longitude  Level
# 0        Sumba Region - Indonesia     -9.18     119.06      2
# 1                       Banda Sea     -6.55     129.64      2
# 2                Java - Indonesia     -7.01     106.63      2
# 3               Seram - Indonesia     -3.30     127.85      2
# 4                       Banda Sea     -6.41     129.54      2
# ...                           ...       ...        ...    ...
# 92882  Talaud Islands - Indonesia      3.24     127.18      2
# 92883        Northern Molucca Sea      2.70     127.10      2
# 92884                  Flores Sea     -7.83     121.07      2
# 92885        Northern Molucca Sea      3.00     127.16      2
# 92886  Sumbawa Region - Indonesia     -8.87     118.95      1
#
# [90152 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90152 entries, 0 to 92886
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        90152 non-null  datetime64[ns]
#  1   time        90152 non-null  object
#  2   day         90152 non-null  object
#  3   moon        90152 non-null  object
#  4   year        90152 non-null  int32
#  5   Depth (km)  90152 non-null  int64
#  6   Magnitude   90152 non-null  float64
#  7   Location    90152 non-null  object
#  8   Latitude    90152 non-null  float64
#  9   Longitude   90152 non-null  float64
#  10  Level       90152 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(2), object(4)
# memory usage: 9.9+ MB

# %% [markdown]
# # EDA
# ## Objective: Investigate the correlation between the depth of earthquakes and the magnitude of earthquakes to determine if there is a relationship between these two factors.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_columns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = df[['Magnitude', 'Depth (km)']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi antara Magnitude dan Depth (km)')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.regplot(x='Magnitude', y='Depth (km)', data=df, scatter_kws={'alpha':0.5})
plt.title('Korelasi antara Magnitude dan Depth (km)')
plt.xlabel('Magnitude')
plt.ylabel('Depth (km)')
plt.grid(True)
plt.show()

# %%
correlation = df['Magnitude'].corr(df['Depth (km)'])
correlation
# Out:
# 0.2356415062203313

# %% [markdown]
# Korelasi antara Magnitude dan Depth (km) sebesar 0.2356415062203313 menunjukkan adanya korelasi positif yang lemah antara kedua variabel tersebut. Artinya, ada kecenderungan bahwa semakin besar magnitudo gempa bumi, semakin dalam kedalaman gempa tersebut cenderung terjadi, meskipun korelasi tersebut tidak terlalu kuat.

# %%
correlation = df['Depth (km)'].corr(df['Magnitude'])
correlation
# Out:
# 0.2356415062203313
